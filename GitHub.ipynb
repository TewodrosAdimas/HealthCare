# %%
from google.colab import drive
import os

# %%
# Connect with my drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# !git config --global user.email "yosefenadagim@gmail.com"
# !git config --global user.name "TewodrosAdimass"

# %%
os.chdir("/content/drive/MyDrive/Healthcare/HealthCare")
# !git add .
# !git commit -m "new clean code"
# !git push
# Out:
# [main d89353c] new clean code
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 GitHub.ipynb
#  rewrite HealthcareLab01.ipynb (92%)
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 157.78 KiB | 3.67 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/TewodrosAdimas/HealthCare.git
#    f715d21..d89353c  main -> main
